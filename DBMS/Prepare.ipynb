# %% [markdown]
# # What is DBMS?

# %% [markdown]
# DBMS (Database Management System) is a software system that manages, stores, and retrieves data efficiently in a structured format.

# %% [markdown]
# # Database Languages

# %% [markdown]
# # 1. Data Definition Language (DDL)
#
# Defining the structure of the database.
#
# DDL is the short name for Data Definition Language, which deals with database schemas and descriptions, of how the data should reside in the database.
#
# **CREATE**: to create a database and its objects like (table, index, views, store procedure, function and triggers)
#
# **ALTER**: alters the structure of the existing database
#
# **DROP**: delete objects from the database
#
# **TRUNCATE**: remove all records from a table, including all spaces allocated for the records are removed
#
# **COMMENT**: add comments to the data dictionary
#
# **RENAME**: rename an object

# %% [markdown]
# # why DDl is used ?

# %% [markdown]
# DDL is used to design how the data will be stored before actually storing the data.

# %% [markdown]
# # DDL Commands

# %% [markdown]
# ## CREATE

# %% [markdown]
# To create new database objects:
#
# Tables
#
# Databases
#
# Indexes
#
# Views

# %%
CREATE TABLE Students (
    id INT PRIMARY KEY,
    name VARCHAR(50),
    age INT
);

# %% [markdown]
# ## ALTER

# %% [markdown]
# ALTER TABLE alters the structure of the existing database
#
# Add column
#
# Delete column
#
# Modify data type
#
# Add constraints

# %%
ALTER TABLE Students
ADD email VARCHAR(100);

ALTER TABLE Students
MODIFY age INT;

ALTER TABLE Students
DROP COLUMN email;

# %% [markdown]
# # DROP
#
# Database Object = Any component that helps store, organize, or access data
#
# delete objects from the database

# %%
DROP TABLE Students;

# %% [markdown]
# # TRUNCATE

# %% [markdown]
# remove all records from a table, including all spaces allocated for the records are removed

# %% [markdown]
# TRUNCATE TABLE Students;

# %% [markdown]
# # RENAME:

# %% [markdown]
# rename an object

# %%
RENAME TABLE Students TO Student_Details;

# %% [markdown]
# # COMMENT

# %% [markdown]
# add comments to the data dictionary

# %% [markdown]
# # Data Manipulation Language (DML)

# %% [markdown]
# DML focuses on manipulating the data stored in the database, enabling users to retrieve, add, update and delete data.

# %% [markdown]
# **INSERT**: insert data into a table
#
# **UPDATE**: updates existing data within a table
#
# **DELETE**: Delete all records from a database table

# %% [markdown]
# ### INSERT

# %%
INSERT INTO Students (id, name, age)
VALUES (1, 'Krishna', 21);

# %% [markdown]
# ### UPDATE

# %%
UPDATE Students
SET age = 22
WHERE id = 1;

# %% [markdown]
# ### DELETE

# %%
DELETE FROM Students
WHERE id = 1;

# %% [markdown]
# # Data Control Language (DCL)
